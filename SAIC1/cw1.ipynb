# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("cw1_dane1.csv")
df1.head()
# Out:
#     I2[A]  U2[V]
# 0  0.0440  8.977
# 1  0.0450  8.972
# 2  0.0466  8.971
# 3  0.0477  8.971
# 4  0.0494  8.971

# %%
plt.scatter(df1["I2[A]"].to_numpy(), df1["U2[V]"].to_numpy())
plt.plot(df1["I2[A]"].to_numpy(), df1["U2[V]"].to_numpy(), 'r')
plt.grid(True)
plt.title("U(I)")
plt.xlabel("I[A]")
plt.ylabel("U[V]")
plt.show()

# %% [markdown]
# $\frac{\Delta U_{2}}{\Delta I_{2}}=\frac{0.016}{0.128}\approx0.125$
