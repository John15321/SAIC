# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("cw1_dane2.csv")
df1.head()
# Out:
#      I[A]  U1[V]  U2[V]
# 0  0.0000      0  0.007
# 1  0.0002      1  0.006
# 2  0.0000      2  0.006
# 3  0.0250      3  1.500
# 4  0.0399      4  2.460

# %%
plt.scatter(df1["U1[V]"].to_numpy(), df1["U2[V]"].to_numpy())
plt.grid(True)
plt.title("$U_{2}(U_{1})$")
plt.xlabel("$U_{2}$")
plt.ylabel("$U_{1}$")
plt.show()
